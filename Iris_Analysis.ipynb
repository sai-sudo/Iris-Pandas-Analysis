# %% [markdown]
# <a href="https://colab.research.google.com/github/sai-sudo/Iris-Pandas-Analysis/blob/main/Iris_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.sample(20)
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm          Species
# 0      1            5.1  ...           0.2      Iris-setosa
# 63    64            6.1  ...           1.4  Iris-versicolor
# 131  132            7.9  ...           2.0   Iris-virginica
# 105  106            7.6  ...           2.1   Iris-virginica
# 13    14            4.3  ...           0.1      Iris-setosa
# 133  134            6.3  ...           1.5   Iris-virginica
# 113  114            5.7  ...           2.0   Iris-virginica
# 73    74            6.1  ...           1.2  Iris-versicolor
# 59    60            5.2  ...           1.4  Iris-versicolor
# 55    56            5.7  ...           1.3  Iris-versicolor
# 65    66            6.7  ...           1.4  Iris-versicolor
# 116  117            6.5  ...           1.8   Iris-virginica
# 3      4            4.6  ...           0.2      Iris-setosa
# 146  147            6.3  ...           1.9   Iris-virginica
# 126  127            6.2  ...           1.8   Iris-virginica
# ...

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.drop_duplicates(subset="Species")
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm          Species
# 0      1            5.1  ...           0.2      Iris-setosa
# 50    51            7.0  ...           1.4  Iris-versicolor
# 100  101            6.3  ...           2.5   Iris-virginica
#
# [3 rows x 6 columns]

# %%
df.value_counts()
# Out:
# Id   SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 150  5.9            3.0           5.1            1.8           Iris-virginica     1
# 56   5.7            2.8           4.5            1.3           Iris-versicolor    1
# 54   5.5            2.3           4.0            1.3           Iris-versicolor    1
# 53   6.9            3.1           4.9            1.5           Iris-versicolor    1
# 52   6.4            3.2           4.5            1.5           Iris-versicolor    1
#                                                                                  ..
# 100  5.7            2.8           4.1            1.3           Iris-versicolor    1
# 99   5.1            2.5           3.0            1.1           Iris-versicolor    1
# 98   6.2            2.9           4.3            1.3           Iris-versicolor    1
# 97   5.7            2.9           4.2            1.3           Iris-versicolor    1
# ...

# %%
df.value_counts("Species")
# Out:
# Species
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# dtype: int64

# %%
df.groupby("Species").max()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       50            5.8           4.4            1.9           0.6
# Iris-versicolor  100            7.0           3.4            5.1           1.8
# Iris-virginica   150            7.9           3.8            6.9           2.5

# %%
df.groupby("Species").min()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            4.3           2.3            1.0           0.1
# Iris-versicolor   51            4.9           2.0            3.0           1.0
# Iris-virginica   101            4.9           2.2            4.5           1.4

# %%
df.groupby("Species").mean()
# Out:
#                     Id  SepalLengthCm  ...  PetalLengthCm  PetalWidthCm
# Species                                ...
# Iris-setosa       25.5          5.006  ...          1.464         0.244
# Iris-versicolor   75.5          5.936  ...          4.260         1.326
# Iris-virginica   125.5          6.588  ...          5.552         2.026
#
# [3 rows x 5 columns]

# %% [markdown]
# Slicing rows:

# %%
data=df[10:16]
data
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa

# %%
print (df[["Id","Species"]].sample(10))
# Out:
#       Id          Species
# 146  147   Iris-virginica
# 86    87  Iris-versicolor
# 112  113   Iris-virginica
# 133  134   Iris-virginica
# 0      1      Iris-setosa
# 39    40      Iris-setosa
# 57    58  Iris-versicolor
# 30    31      Iris-setosa
# 65    66  Iris-versicolor
# 6      7      Iris-setosa

# %%
df.iloc[10:16]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 13  14            4.3           3.0            1.1           0.1  Iris-setosa
# 14  15            5.8           4.0            1.2           0.2  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa

# %%
df.loc[df["Species"]== "Iris-virginica"]
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 100  101            6.3  ...           2.5  Iris-virginica
# 101  102            5.8  ...           1.9  Iris-virginica
# 102  103            7.1  ...           2.1  Iris-virginica
# 103  104            6.3  ...           1.8  Iris-virginica
# 104  105            6.5  ...           2.2  Iris-virginica
# 105  106            7.6  ...           2.1  Iris-virginica
# 106  107            4.9  ...           1.7  Iris-virginica
# 107  108            7.3  ...           1.8  Iris-virginica
# 108  109            6.7  ...           1.8  Iris-virginica
# 109  110            7.2  ...           2.5  Iris-virginica
# 110  111            6.5  ...           2.0  Iris-virginica
# 111  112            6.4  ...           1.9  Iris-virginica
# 112  113            6.8  ...           2.1  Iris-virginica
# 113  114            5.7  ...           2.0  Iris-virginica
# 114  115            5.8  ...           2.4  Iris-virginica
# ...

# %%
min_len=df["SepalLengthCm"].min()
print (min_len)
# Out:
# 4.3

# %%
max_len=df["SepalLengthCm"].max()
max_len
# Out:
# 7.9

# %%
df["Total"]=df[df.columns].sum(axis=1)
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  ...  PetalWidthCm         Species  Total
# 0      1            5.1           3.5  ...           0.2     Iris-setosa   22.4
# 1      2            4.9           3.0  ...           0.2     Iris-setosa   23.0
# 2      3            4.7           3.2  ...           0.2     Iris-setosa   24.8
# 3      4            4.6           3.1  ...           0.2     Iris-setosa   26.8
# 4      5            5.0           3.6  ...           0.2     Iris-setosa   30.4
# ..   ...            ...           ...  ...           ...             ...    ...
# 145  146            6.7           3.0  ...           2.3  Iris-virginica  326.4
# 146  147            6.3           2.5  ...           1.9  Iris-virginica  325.4
# 147  148            6.5           3.0  ...           2.0  Iris-virginica  329.4
# 148  149            6.2           3.4  ...           2.3  Iris-virginica  332.6
# 149  150            5.9           3.0  ...           1.8  Iris-virginica  331.6
#
# ...

# %%
df.corr(method='pearson')
# Out:
#                      Id  SepalLengthCm  ...  PetalWidthCm     Total
# Id             1.000000       0.716676  ...      0.899759  0.999370
# SepalLengthCm  0.716676       1.000000  ...      0.817954  0.738612
# SepalWidthCm  -0.397729      -0.109369  ...     -0.356544 -0.389048
# PetalLengthCm  0.882747       0.871754  ...      0.962757  0.897059
# PetalWidthCm   0.899759       0.817954  ...      1.000000  0.911904
# Total          0.999370       0.738612  ...      0.911904  1.000000
#
# [6 rows x 6 columns]

# %% [markdown]
# # **Visual Analysis of the Data**

# %%
sns.countplot(x="Species",data=df)

# %%
sns.pairplot(df.drop(['Id'],axis =1), hue="Species")
